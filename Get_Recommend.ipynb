# %%
from gensim.models import Word2Vec
model = Word2Vec.load('drive/Colab Notebooks/model.bin')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
import pandas as pd


df = pd.read_csv('drive/Colab Notebooks/raw-data.csv',encoding = "ISO-8859-1")
df = df.drop(['title','citeulike.id'], axis=1)
df = df.dropna().reset_index(drop=True)
df.head()
# Out:
#    doc.id  ...                                       raw.abstract
# 0       1  ...  To elucidate the organizational and evolutiona...
# 1       2  ...  Advanced technologies and biology have extreme...
# 2       3  ...  The study of networks pervades all of science,...
# 3       4  ...  Comprehensive protein protein interaction maps...
# 4       5  ...  The small-world phenomenon â the principle t...
#
# [5 rows x 3 columns]

# %%
import numpy as np
import nltk
import re

nltk.download('stopwords')
wpt = nltk.WordPunctTokenizer()
stop_words = nltk.corpus.stopwords.words('english')

def cleaning(doc):
    doc = re.sub(r'[^a-zA-Z\s]', '', doc, re.I|re.A)
    doc = doc.lower()
    doc = doc.strip()
    tokens = wpt.tokenize(doc)
    filtered_tokens = [token for token in tokens if token not in stop_words]
    doc = ' '.join(filtered_tokens)
    return doc
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Với 1 user cụ thể
df_interact = pd.read_csv('drive/Colab Notebooks/user-info.csv',encoding = "ISO-8859-1")
df_interact.drop(['rating'], axis=1)
df_interact=df_interact[df_interact['user.id'] == 1]

# %%
df_interact
# Out:
#     user.id  doc.id  rating
# 0         1     496       1
# 1         1    1632       1
# 2         1    2318       1
# 3         1    2527       1
# 4         1    2847       1
# 5         1    2932       1
# 6         1    3172       1
# 7         1    3298       1
# 8         1    3333       1
# 9         1    3405       1
# 10        1    3592       1
# 11        1    3596       1
# 12        1    3771       1
# 13        1    3951       1
# 14        1    4627       1
# 15        1    4663       1
# 16        1    4872       1
# 17        1    4890       1
# 18        1    5115       1
# 19        1    5325       1
# 20        1    5326       1
# 21        1    5615       1
# 22        1    5992       1
# 23        1    6104       1
# 24        1    6875       1
# 25        1    6969       1
# 26        1    7107       1
# 27        1    7802       1
# 28        1    7868       1
# 29        1    8904       1
# ..      ...     ...     ...
# 40        1   11321       1
# ...

# %%
#Mã các bài báo mà user đã đọc
history_read = df_interact[df_interact['user.id']==1]['doc.id'].values
history_read
# Out:
# array([  496,  1632,  2318,  2527,  2847,  2932,  3172,  3298,  3333,
#         3405,  3592,  3596,  3771,  3951,  4627,  4663,  4872,  4890,
#         5115,  5325,  5326,  5615,  5992,  6104,  6875,  6969,  7107,
#         7802,  7868,  8904,  9908, 10009, 10205, 10273, 10289, 10509,
#        10589, 11010, 11106, 11227, 11321, 11651, 11854, 11920, 12685,
#        12717, 12803, 12804, 12805, 12806, 12832, 12917, 13173, 13188,
#        13364, 13924, 13925, 14663, 14677, 14852, 15027, 15166, 15192,
#        15283, 15301, 15337, 15834, 15895, 16164, 16425])

# %%
#Thử recommend cho 1 bài
doc1 = df[df['doc.id']==1632]['raw.abstract'].values
score = []
print(doc1[0])
rec_abstract = df['raw.abstract'].values
rec_title = df['raw.title'].values
for i in range(0,len(rec_abstract)):
  score.append(model.wv.wmdistance(cleaning(doc1[0]),cleaning(rec_abstract[i])))
title_sort = np.argsort(score)
title_sort = title_sort[:5]
for title_index in title_sort:
  print(rec_title[title_index+1])

# %%
#Với mỗi user, 1 bài báo đã đọc, gợi ý 5 bài báo có nội dung liên quan
#Vi du user.id = 1
rec_abstract = df['raw.abstract'].values
rec_title = df['raw.title'].values

for history_id in history_read:
  
  history_item = df[df['doc.id']==history_id]['raw.abstract'].values
  
  print(df[df['doc.id']==history_id]['raw.title'].values)
  print("Recommdend:")
  
  score = []  
  for i in range(0,len(rec_abstract)):
    score.append(model.wv.wmdistance(cleaning(history_item[0]),cleaning(rec_abstract[i])))
  title_sort = np.argsort(score)
  title_sort = title_sort[1:6]
  for title_index in title_sort:
    print(rec_title[title_index+1])
  
  print("--------------------------")
# Out:
# ['The Molecular Biology Database Collection: 2005 update']
# Recommdend:
# Genome engineering
# SNPchip: R classes and methods for SNP array data
# Working Knowledge
# Integrating the statistical analysis of spatial data in ecology
# Mutations affecting segment number and polarity in Drosophila.
# --------------------------
# ['Cytoscape: a software environment for integrated models of biomolecular interaction networks.']
# Recommdend:
# Gene networks: how to put the function in genomics.
# Theory building from cases: Opportunities and challenges
# Advanced Interaction in Context
# Explosive Percolation in Random Networks
# iHOPerator: user-scripting a personalized bioinformatics Web, starting with the iHOP website.
# --------------------------
# ['Are protein-protein interfaces more conserved in sequence than the rest of the protein surface?']
# Recommdend:
# Unleashing Web 2.0: From Concepts to Creativity
# Constructing Common Information Spaces.
# Stochasticity and cell fate.
# ...
